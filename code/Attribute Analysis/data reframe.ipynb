# %%
import pandas as pd
import json
import ast

# %%
data1 = pd.read_csv('mnq.csv')
data1
# Out:
# /Users/jianzhuoliu/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (14) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#        Unnamed: 0             business_id  stars_x  RestaurantsTakeOut  HasTV  \
# 0               0  SZU9c8V2GuREDN5KgyHFJw        5                True  False
# 1               1  eL4lyE7LNoXEMvpcJ8WNVw        5                True   True
# 2               2  eL4lyE7LNoXEMvpcJ8WNVw        3                True  False
# 3               3  SZU9c8V2GuREDN5KgyHFJw        5                True   True
# 4               4  SZU9c8V2GuREDN5KgyHFJw        5                True   True
# ...           ...                     ...      ...                 ...    ...
# 41997       41997  QLHgjBHBoeIUoEvIPvjHnw        4                True  False
# 41998       41998  QBNATcq7Stx9LxcSq16W7w        5                True  False
# ...

# %%
attri = data1['Ambience']
df=pd.DataFrame(attri)
n = data1[['business_id', 'stars_x','RestaurantsTakeOut','HasTV','NoiseLevel','Alcohol','RestaurantsGoodForGroups','BusinessAcceptsCreditCards','Caters','RestaurantsAttire','BikeParking','GoodForKids','RestaurantsReservations','BusinessAcceptsBitcoin','WiFi','HappyHour','CoatCheck','RestaurantsDelivery','OutdoorSeating','WheelchairAccessible','RestaurantsTableService','ByAppointmentOnly','DogsAllowed','Music','BusinessParking','GoodForMeal']]
a = df.loc[0]
z = ast.literal_eval(a["Ambience"])
df1 = pd.DataFrame([z])

# %%
df1
# Out:
#    touristy  hipster  romantic  divey  intimate  trendy  upscale  classy  \
# 0     False    False     False  False     False   False    False   False
#
#    casual
# 0    True

# %%
result6
# Out:
#                   business_id  stars_x  RestaurantsTakeOut  HasTV NoiseLevel  \
# 0      SZU9c8V2GuREDN5KgyHFJw        5                True  False    average
# 1      eL4lyE7LNoXEMvpcJ8WNVw        5                True   True    average
# 2      eL4lyE7LNoXEMvpcJ8WNVw        3                True  False      quiet
# 3      SZU9c8V2GuREDN5KgyHFJw        5                True   True    average
# 4      SZU9c8V2GuREDN5KgyHFJw        5                True   True    average
# ...                       ...      ...                 ...    ...        ...
# 27996  tthy48ZIX_wfY8Dy0Dvg6w        5                True   True      quiet
# 27997  tthy48ZIX_wfY8Dy0Dvg6w        5                True  False    average
# 27998  tthy48ZIX_wfY8Dy0Dvg6w        5                True   True      quiet
# 27999  tthy48ZIX_wfY8Dy0Dvg6w        5                True  False    average
# 28000  tthy48ZIX_wfY8Dy0Dvg6w        5                True  False    average
#
# ...

# %%
data1 = pd.read_csv('mnq.csv')

attri = data1['Ambience']
df=pd.DataFrame(attri)
n = data1[['business_id', 'stars_x','RestaurantsTakeOut','HasTV','NoiseLevel','Alcohol','RestaurantsGoodForGroups','BusinessAcceptsCreditCards','Caters','RestaurantsAttire','BikeParking','GoodForKids','RestaurantsReservations','BusinessAcceptsBitcoin','WiFi','HappyHour','CoatCheck','RestaurantsDelivery','OutdoorSeating','WheelchairAccessible','RestaurantsTableService','ByAppointmentOnly','DogsAllowed','Music','BusinessParking','GoodForMeal']]
f=df1
for i in range (1,2001):
    m = df.loc[i]
    a = ast.literal_eval(m["Ambience"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result1 = pd.concat([n, f], axis=1, join="inner")
# Out:
# /Users/jianzhuoliu/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (14) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
result1
# Out:
#                  business_id  stars_x  RestaurantsTakeOut  HasTV NoiseLevel  \
# 0     SZU9c8V2GuREDN5KgyHFJw        5                True  False    average
# 1     eL4lyE7LNoXEMvpcJ8WNVw        5                True   True    average
# 2     eL4lyE7LNoXEMvpcJ8WNVw        3                True  False      quiet
# 3     SZU9c8V2GuREDN5KgyHFJw        5                True   True    average
# 4     SZU9c8V2GuREDN5KgyHFJw        5                True   True    average
# ...                      ...      ...                 ...    ...        ...
# 1996  eL4lyE7LNoXEMvpcJ8WNVw        5               False  False    average
# 1997  H-1qpp_77KggOAr9htUrEw        4                True   True    average
# 1998  SZU9c8V2GuREDN5KgyHFJw        5               False   True    average
# 1999  SZU9c8V2GuREDN5KgyHFJw        5               False  False    average
# 2000  1FURjeGJi_LBXcJQg8eskw        5                True   True    average
#
# ...

# %%
for i in range (2001,4001):
    m = df.loc[i]
    a = ast.literal_eval(m["Ambience"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result2 = pd.concat([n, f], axis=1, join="inner")

# %%
for i in range (4001,10001):
    m = df.loc[i]
    a = ast.literal_eval(m["Ambience"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result3 = pd.concat([n, f], axis=1, join="inner")

# %%
for i in range (10001,16001):
    m = df.loc[i]
    a = ast.literal_eval(m["Ambience"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result4 = pd.concat([n, f], axis=1, join="inner")

# %%
for i in range (16001,22001):
    m = df.loc[i]
    a = ast.literal_eval(m["Ambience"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result5 = pd.concat([n, f], axis=1, join="inner")

# %%
for i in range (22001,28001):
    m = df.loc[i]
    a = ast.literal_eval(m["Ambience"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result6 = pd.concat([n, f], axis=1, join="inner")

# %% [raw]
# result6

# %%
for i in range (28001,34001):
    m = df.loc[i]
    a = ast.literal_eval(m["Ambience"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result7 = pd.concat([n, f], axis=1, join="inner")

# %%
for i in range (34001,40001):
    m = df.loc[i]
    a = ast.literal_eval(m["Ambience"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result8 = pd.concat([n, f], axis=1, join="inner")

# %%
for i in range (40001,42002):
    m = df.loc[i]
    a = ast.literal_eval(m["Ambience"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
resultn = pd.concat([n, f], axis=1, join="inner")

# %%
resultn
# Out:
#                   business_id  stars_x  RestaurantsTakeOut  HasTV NoiseLevel  \
# 0      SZU9c8V2GuREDN5KgyHFJw        5                True  False    average
# 1      eL4lyE7LNoXEMvpcJ8WNVw        5                True   True    average
# 2      eL4lyE7LNoXEMvpcJ8WNVw        3                True  False      quiet
# 3      SZU9c8V2GuREDN5KgyHFJw        5                True   True    average
# 4      SZU9c8V2GuREDN5KgyHFJw        5                True   True    average
# ...                       ...      ...                 ...    ...        ...
# 41997  QLHgjBHBoeIUoEvIPvjHnw        4                True  False    average
# 41998  QBNATcq7Stx9LxcSq16W7w        5                True  False      quiet
# 41999  QLHgjBHBoeIUoEvIPvjHnw        5                True  False      quiet
# 42000  krTxH1a9kzWgwvt3PVH8pQ        5                True  False    average
# 42001  YiSr-W5BBX6uXnhWPxk82Q        5                True  False    average
#
# ...

# %%
attri = resultn['GoodForMeal']
df=pd.DataFrame(attri)
n = resultn[['business_id', 'stars_x','RestaurantsTakeOut','HasTV','NoiseLevel','Alcohol','RestaurantsGoodForGroups','BusinessAcceptsCreditCards','Caters','RestaurantsAttire','BikeParking','GoodForKids','RestaurantsReservations','BusinessAcceptsBitcoin','WiFi','HappyHour','CoatCheck','RestaurantsDelivery','OutdoorSeating','WheelchairAccessible','RestaurantsTableService','ByAppointmentOnly','DogsAllowed','Music','BusinessParking']]
a = df.loc[0]
z = ast.literal_eval(a["GoodForMeal"])
df1 = pd.DataFrame([z])

# %%
attri = resultn['GoodForMeal']
df=pd.DataFrame(attri)
n = resultn[['business_id', 'stars_x','RestaurantsTakeOut','HasTV','NoiseLevel','Alcohol','RestaurantsGoodForGroups','BusinessAcceptsCreditCards','Caters','RestaurantsAttire','BikeParking','GoodForKids','RestaurantsReservations','BusinessAcceptsBitcoin','WiFi','HappyHour','CoatCheck','RestaurantsDelivery','OutdoorSeating','WheelchairAccessible','RestaurantsTableService','ByAppointmentOnly','DogsAllowed','Music','BusinessParking','touristy','hipster','romantic','divey','intimate','trendy','upscale','classy','casual']]
f=df1
for i in range (1,2001):
    m = df.loc[i]
    a = ast.literal_eval(m["GoodForMeal"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result1 = pd.concat([n, f], axis=1, join="inner")

# %%
result1
# Out:
#                  business_id  stars_x  RestaurantsTakeOut  HasTV NoiseLevel  \
# 0     SZU9c8V2GuREDN5KgyHFJw        5                True  False    average
# 1     eL4lyE7LNoXEMvpcJ8WNVw        5                True   True    average
# 2     eL4lyE7LNoXEMvpcJ8WNVw        3                True  False      quiet
# 3     SZU9c8V2GuREDN5KgyHFJw        5                True   True    average
# 4     SZU9c8V2GuREDN5KgyHFJw        5                True   True    average
# ...                      ...      ...                 ...    ...        ...
# 1996  eL4lyE7LNoXEMvpcJ8WNVw        5               False  False    average
# 1997  H-1qpp_77KggOAr9htUrEw        4                True   True    average
# 1998  SZU9c8V2GuREDN5KgyHFJw        5               False   True    average
# 1999  SZU9c8V2GuREDN5KgyHFJw        5               False  False    average
# 2000  1FURjeGJi_LBXcJQg8eskw        5                True   True    average
#
# ...

# %%
for i in range (2001,10001):
    m = df.loc[i]
    a = ast.literal_eval(m["GoodForMeal"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result1 = pd.concat([n, f], axis=1, join="inner")

# %%
result1
# Out:
#                   business_id  stars_x  RestaurantsTakeOut  HasTV NoiseLevel  \
# 0      SZU9c8V2GuREDN5KgyHFJw        5                True  False    average
# 1      eL4lyE7LNoXEMvpcJ8WNVw        5                True   True    average
# 2      eL4lyE7LNoXEMvpcJ8WNVw        3                True  False      quiet
# 3      SZU9c8V2GuREDN5KgyHFJw        5                True   True    average
# 4      SZU9c8V2GuREDN5KgyHFJw        5                True   True    average
# ...                       ...      ...                 ...    ...        ...
# 9997   U3grYFIeu6RgAAQgdriHww        1                True  False      quiet
# 9998   U3grYFIeu6RgAAQgdriHww        5               False  False    average
# 9999   U3grYFIeu6RgAAQgdriHww        4               False  False    average
# 10000  U3grYFIeu6RgAAQgdriHww        1               False  False    average
# 10001  U3grYFIeu6RgAAQgdriHww        5               False  False    average
#
# ...

# %%
for i in range (10001,18001):
    m = df.loc[i]
    a = ast.literal_eval(m["GoodForMeal"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result2 = pd.concat([n, f], axis=1, join="inner")

# %%
result2
# Out:
#                   business_id  stars_x  RestaurantsTakeOut  HasTV NoiseLevel  \
# 0      SZU9c8V2GuREDN5KgyHFJw        5                True  False    average
# 1      eL4lyE7LNoXEMvpcJ8WNVw        5                True   True    average
# 2      eL4lyE7LNoXEMvpcJ8WNVw        3                True  False      quiet
# 3      SZU9c8V2GuREDN5KgyHFJw        5                True   True    average
# 4      SZU9c8V2GuREDN5KgyHFJw        5                True   True    average
# ...                       ...      ...                 ...    ...        ...
# 17996  iBBV8vesQ8fo2IQA7an1JA        5               False  False    average
# 17997  iBBV8vesQ8fo2IQA7an1JA        5                True   True    average
# 17998  iBBV8vesQ8fo2IQA7an1JA        4                True  False      quiet
# 17999                  #NAME?        3                True  False    average
# 18000  iBBV8vesQ8fo2IQA7an1JA        4                True   True    average
#
# ...

# %%
for i in range (18001,26001):
    m = df.loc[i]
    a = ast.literal_eval(m["GoodForMeal"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result3 = pd.concat([n, f], axis=1, join="inner")

# %%
for i in range (26001,34001):
    m = df.loc[i]
    a = ast.literal_eval(m["GoodForMeal"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result4 = pd.concat([n, f], axis=1, join="inner")

# %%
for i in range (34001,40001):
    m = df.loc[i]
    a = ast.literal_eval(m["GoodForMeal"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result5 = pd.concat([n, f], axis=1, join="inner")

# %%
for i in range (40001,42002):
    m = df.loc[i]
    a = ast.literal_eval(m["GoodForMeal"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result6 = pd.concat([n, f], axis=1, join="inner")

# %%
result6
# Out:
#                   business_id  stars_x  RestaurantsTakeOut  HasTV NoiseLevel  \
# 0      SZU9c8V2GuREDN5KgyHFJw        5                True  False    average
# 1      eL4lyE7LNoXEMvpcJ8WNVw        5                True   True    average
# 2      eL4lyE7LNoXEMvpcJ8WNVw        3                True  False      quiet
# 3      SZU9c8V2GuREDN5KgyHFJw        5                True   True    average
# 4      SZU9c8V2GuREDN5KgyHFJw        5                True   True    average
# ...                       ...      ...                 ...    ...        ...
# 41997  QLHgjBHBoeIUoEvIPvjHnw        4                True  False    average
# 41998  QBNATcq7Stx9LxcSq16W7w        5                True  False      quiet
# 41999  QLHgjBHBoeIUoEvIPvjHnw        5                True  False      quiet
# 42000  krTxH1a9kzWgwvt3PVH8pQ        5                True  False    average
# 42001  YiSr-W5BBX6uXnhWPxk82Q        5                True  False    average
#
# ...

# %%
attri = result6['Music']
df=pd.DataFrame(attri)
n = result6[['business_id', 'stars_x','RestaurantsTakeOut','HasTV','NoiseLevel','Alcohol','RestaurantsGoodForGroups','BusinessAcceptsCreditCards','Caters','RestaurantsAttire','BikeParking','GoodForKids','RestaurantsReservations','BusinessAcceptsBitcoin','WiFi','HappyHour','CoatCheck','RestaurantsDelivery','OutdoorSeating','WheelchairAccessible','RestaurantsTableService','ByAppointmentOnly','DogsAllowed','Music']]
a = df.loc[0]
z = ast.literal_eval(a["Music"])
df1 = pd.DataFrame([z])

# %%
attri = result6['Music']
df=pd.DataFrame(attri)
n = result6[['business_id', 'stars_x','RestaurantsTakeOut','HasTV','NoiseLevel','Alcohol','RestaurantsGoodForGroups','BusinessAcceptsCreditCards','Caters','RestaurantsAttire','BikeParking','GoodForKids','RestaurantsReservations','BusinessAcceptsBitcoin','WiFi','HappyHour','CoatCheck','RestaurantsDelivery','OutdoorSeating','WheelchairAccessible','RestaurantsTableService','ByAppointmentOnly','DogsAllowed','touristy','hipster','romantic','divey','intimate','trendy','upscale','classy','casual','breakfast','brunch','lunch','latenight','dessert']]
f=df1
for i in range (1,2001):
    m = df.loc[i]
    a = ast.literal_eval(m["Music"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result1 = pd.concat([n, f], axis=1, join="inner")

# %%
for i in range (2001,10001):
    m = df.loc[i]
    a = ast.literal_eval(m["Music"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result2 = pd.concat([n, f], axis=1, join="inner")

# %%
for i in range (10001,20001):
    m = df.loc[i]
    a = ast.literal_eval(m["Music"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result3 = pd.concat([n, f], axis=1, join="inner")

# %%
for i in range (20001,30001):
    m = df.loc[i]
    a = ast.literal_eval(m["Music"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result3 = pd.concat([n, f], axis=1, join="inner")

# %%
for i in range (30001,40001):
    m = df.loc[i]
    a = ast.literal_eval(m["Music"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result3 = pd.concat([n, f], axis=1, join="inner")

# %%
for i in range (30001,42002):
    m = df.loc[i]
    a = ast.literal_eval(m["Music"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result3 = pd.concat([n, f], axis=1, join="inner")

# %%
result3
# Out:
#                   business_id  stars_x  RestaurantsTakeOut  HasTV NoiseLevel  \
# 0      SZU9c8V2GuREDN5KgyHFJw        5                True  False    average
# 1      eL4lyE7LNoXEMvpcJ8WNVw        5                True   True    average
# 2      eL4lyE7LNoXEMvpcJ8WNVw        3                True  False      quiet
# 3      SZU9c8V2GuREDN5KgyHFJw        5                True   True    average
# 4      SZU9c8V2GuREDN5KgyHFJw        5                True   True    average
# ...                       ...      ...                 ...    ...        ...
# 41997  QLHgjBHBoeIUoEvIPvjHnw        4                True  False    average
# 41998  QBNATcq7Stx9LxcSq16W7w        5                True  False      quiet
# 41999  QLHgjBHBoeIUoEvIPvjHnw        5                True  False      quiet
# 42000  krTxH1a9kzWgwvt3PVH8pQ        5                True  False    average
# 42001  YiSr-W5BBX6uXnhWPxk82Q        5                True  False    average
#
# ...

# %%
result3.to_csv('answer.csv')
