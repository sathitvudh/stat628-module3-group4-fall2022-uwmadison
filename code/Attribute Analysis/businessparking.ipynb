# %%
import pandas as pd
import json
import ast

# %%
data1 = pd.read_csv("data3.csv")
data1
# Out:
#        Unnamed: 0             business_id  stars_x  \
# 0               1  SZU9c8V2GuREDN5KgyHFJw        5
# 1               2  eL4lyE7LNoXEMvpcJ8WNVw        5
# 2               3  eL4lyE7LNoXEMvpcJ8WNVw        3
# 3               4  SZU9c8V2GuREDN5KgyHFJw        5
# 4               5  SZU9c8V2GuREDN5KgyHFJw        5
# ...           ...                     ...      ...
# 41646       41647  QLHgjBHBoeIUoEvIPvjHnw        4
# 41647       41648  QBNATcq7Stx9LxcSq16W7w        5
# 41648       41649  QLHgjBHBoeIUoEvIPvjHnw        5
# 41649       41650  krTxH1a9kzWgwvt3PVH8pQ        5
# 41650       41651  YiSr-W5BBX6uXnhWPxk82Q        5
#
#                                          BusinessParking
# 0      {'garage': False, 'street': False, 'validated'...
# 1      {'garage': False, 'street': True, 'validated':...
# 2      {'garage': True, 'street': True, 'validated': ...
# 3      {'garage': False, 'street': True, 'validated':...
# 4      {'garage': False, 'street': True, 'validated':...
# ...

# %%
attri = data1['BusinessParking']
df=pd.DataFrame(attri)
n = data1[['business_id', 'stars_x']]
a = df.loc[0]
z = ast.literal_eval(a["BusinessParking"])
df1 = pd.DataFrame([z])

# %%
data1 = pd.read_csv("data3.csv")
attri = data1['BusinessParking']
df=pd.DataFrame(attri)
n = data1[['business_id', 'stars_x']]
f=df1
for i in range (0,2001):
    m = df.loc[i]
    a = ast.literal_eval(m["BusinessParking"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result1 = pd.concat([n, f], axis=1, join="inner")

# %%
for i in range (2001,8001):
    m = df.loc[i]
    a = ast.literal_eval(m["BusinessParking"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result2 = pd.concat([n, f], axis=1, join="inner")

# %%
for i in range (8001,14001):
    m = df.loc[i]
    a = ast.literal_eval(m["BusinessParking"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result2 = pd.concat([n, f], axis=1, join="inner")

# %%
for i in range (14001,20001):
    m = df.loc[i]
    a = ast.literal_eval(m["BusinessParking"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result4 = pd.concat([n, f], axis=1, join="inner")

# %%
for i in range (20001,26001):
    m = df.loc[i]
    a = ast.literal_eval(m["BusinessParking"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result5 = pd.concat([n, f], axis=1, join="inner")

# %%
for i in range (26001,32001):
    m = df.loc[i]
    a = ast.literal_eval(m["BusinessParking"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result6 = pd.concat([n, f], axis=1, join="inner")

# %%
for i in range (32001,38001):
    m = df.loc[i]
    a = ast.literal_eval(m["BusinessParking"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result7 = pd.concat([n, f], axis=1, join="inner")

# %%
for i in range (38001,41651):
    m = df.loc[i]
    a = ast.literal_eval(m["BusinessParking"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result8 = pd.concat([n, f], axis=1, join="inner")

# %%
result8.to_csv("businessparking.csv")

# %%
result8
# Out:
#                   business_id  stars_x garage street validated    lot  valet  \
# 0      SZU9c8V2GuREDN5KgyHFJw        5  False  False      True  False  False
# 1      eL4lyE7LNoXEMvpcJ8WNVw        5  False  False      True  False  False
# 2      eL4lyE7LNoXEMvpcJ8WNVw        3  False   True      True  False   True
# 3      SZU9c8V2GuREDN5KgyHFJw        5  False   True      True  False   True
# 4      SZU9c8V2GuREDN5KgyHFJw        5  False  False      True  False  False
# ...                       ...      ...    ...    ...       ...    ...    ...
# 41646  QLHgjBHBoeIUoEvIPvjHnw        4  False   True     False   True  False
# 41647  QBNATcq7Stx9LxcSq16W7w        5  False   True     False   True  False
# 41648  QLHgjBHBoeIUoEvIPvjHnw        5   True   True     False  False   True
# 41649  krTxH1a9kzWgwvt3PVH8pQ        5  False   True     False   True  False
# 41650  YiSr-W5BBX6uXnhWPxk82Q        5  False  False     False   True  False
#
#          0
# 0      NaN
# 1      NaN
# ...
