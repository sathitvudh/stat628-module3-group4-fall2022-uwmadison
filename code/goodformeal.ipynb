# %%
import pandas as pd
import json

# %%
data = pd.read_csv("bars_list_ca.csv")
data
# Out:
#        Unnamed: 0             business_id  stars_x  \
# 0              10  SZU9c8V2GuREDN5KgyHFJw        5
# 1              22  eL4lyE7LNoXEMvpcJ8WNVw        5
# 2              37  eL4lyE7LNoXEMvpcJ8WNVw        3
# 3              40  SZU9c8V2GuREDN5KgyHFJw        5
# 4              48  SZU9c8V2GuREDN5KgyHFJw        5
# ...           ...                     ...      ...
# 44688      594302  q-1ICFSqs2MwDGfe5tX-SQ        5
# 44689      594309  wMZAnrfwV-qHiV5zdTSrzw        5
# 44690      594337  KSYONgGtrK0nKXfroB-bwg        2
# 44691      594345  fiQxkb1pfPpvrr0oYYYBcA        5
# 44692      594348  r2IhvKZQ_wLR5mLBnPOilg        4
#
#                                                     text  \
# 0      We were a bit weary about trying the Shellfish...
# 1      Great, beautiful spot to do wine tasting. I lo...
# 2      This was a tough one!   On the merits of the w...
# 3      I love trying fresh seafood on piers, wharfs a...
# 4      Super delish!! No frills! Just great sea food,...
# ...

# %%
attri = data['attributes']
attri
len(attri)
# Out:
# 44693

# %%
attri
# Out:
# 0        {'OutdoorSeating': 'True', 'RestaurantsAttire'...
# 1        {'RestaurantsGoodForGroups': 'True', 'OutdoorS...
# 2        {'RestaurantsGoodForGroups': 'True', 'OutdoorS...
# 3        {'OutdoorSeating': 'True', 'RestaurantsAttire'...
# 4        {'OutdoorSeating': 'True', 'RestaurantsAttire'...
#                                ...
# 44688    {'Music': "{'dj': False}", 'NoiseLevel': "'ave...
# 44689    {'RestaurantsTakeOut': 'True', 'WheelchairAcce...
# 44690    {'WiFi': "u'no'", 'BusinessAcceptsCreditCards'...
# 44691    {'DogsAllowed': 'True', 'HappyHour': 'True', '...
# 44692    {'BusinessAcceptsCreditCards': 'True', 'DogsAl...
# Name: attributes, Length: 44693, dtype: object

# %%
df=pd.DataFrame(attri)

# %%
z = df.loc[0]
z
# Out:
# attributes    {'OutdoorSeating': 'True', 'RestaurantsAttire'...
# Name: 0, dtype: object

# %%
q = df.loc[1]
w = ast.literal_eval(q["attributes"])
w
df2 = pd.DataFrame([w])
q
# Out:
# attributes    {'RestaurantsGoodForGroups': 'True', 'OutdoorS...
# Name: 1, dtype: object

# %%
df2

# %%
f = pd.concat([df1,df2], axis=0, ignore_index=True)

# %%
import ast
a = ast.literal_eval(z["attributes"])
a
# Out:
# {'OutdoorSeating': 'True',
#  'RestaurantsAttire': "'casual'",
#  'RestaurantsReservations': 'False',
#  'BusinessAcceptsCreditCards': 'True',
#  'NoiseLevel': "u'average'",
#  'RestaurantsPriceRange2': '2',
#  'RestaurantsGoodForGroups': 'False',
#  'WiFi': "u'no'",
#  'Alcohol': "'beer_and_wine'",
#  'RestaurantsTakeOut': 'True',
#  'BikeParking': 'True',
#  'BusinessParking': "{'garage': False, 'street': False, 'validated': True, 'lot': False, 'valet': False}",
#  'HasTV': 'False',
#  'ByAppointmentOnly': 'False',
#  'GoodForKids': 'True',
#  'Caters': 'False',
#  'Ambience': "{'touristy': False, 'hipster': False, 'romantic': False, 'divey': False, 'intimate': False, 'trendy': False, 'upscale': False, 'classy': True, 'casual': True}",
#  'RestaurantsDelivery': 'True',
#  'HappyHour': 'False',
#  'Music': "{u'dj': False, u'live': False, u'jukebox': False, u'video': False, u'background_music': False, u'karaoke': False, u'no_music': False}",
# ...

# %%
df1=pd.DataFrame([a])
df1
# Out:
#   GoodForKids RestaurantsGoodForGroups RestaurantsAttire  \
# 0        True                     True         u'casual'
#
#   BusinessAcceptsCreditCards Caters RestaurantsPriceRange2           Alcohol  \
# 0                       True   True                      2  u'beer_and_wine'
#
#   RestaurantsTakeOut                                    BusinessParking  \
# 0               True  {'garage': False, 'street': True, 'validated':...
#
#   BikeParking  ...     WiFi GoodForDancing RestaurantsDelivery  \
# 0        True  ...  u'free'          False                True
#
#   WheelchairAccessible                                           Ambience  \
# 0                 True  {'touristy': False, 'hipster': False, 'romanti...
#
#   OutdoorSeating BusinessAcceptsBitcoin DogsAllowed HappyHour   BYOB
# 0           True                  False       False     False  False
#
# [1 rows x 27 columns]

# %%
m = data[['business_id', 'stars_x']]
result = pd.concat([m, f], axis=1, join="inner")
result
result.to_csv("result.csv")

# %%
data = pd.read_csv("bars_list_ca.csv")
attri = data['attributes']
df=pd.DataFrame(attri)
n = data[['business_id', 'stars_x']]
f=df1
for i in range (0,2001):
    m = df.loc[i]
    a = ast.literal_eval(m["attributes"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result1 = pd.concat([n, f], axis=1, join="inner")

# %%
result1
# Out:
#                  business_id  stars_x GoodForKids RestaurantsGoodForGroups  \
# 0     SZU9c8V2GuREDN5KgyHFJw        5        True                     True
# 1     eL4lyE7LNoXEMvpcJ8WNVw        5        True                    False
# 2     eL4lyE7LNoXEMvpcJ8WNVw        3        True                    False
# 3     SZU9c8V2GuREDN5KgyHFJw        5        True                     True
# 4     SZU9c8V2GuREDN5KgyHFJw        5       False                     True
# ...                      ...      ...         ...                      ...
# 1997  H-1qpp_77KggOAr9htUrEw        4        True                    False
# 1998  SZU9c8V2GuREDN5KgyHFJw        5       False                     True
# 1999  SZU9c8V2GuREDN5KgyHFJw        5       False                     True
# 2000  1FURjeGJi_LBXcJQg8eskw        5        True                    False
# 2001  ywXa1pDqHPe9tOPx0yJFUg        4        True                    False
#
#      RestaurantsAttire BusinessAcceptsCreditCards Caters  \
# ...

# %%
for i in range (2001,4001):
    m = df.loc[i]
    a = ast.literal_eval(m["attributes"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result2 = pd.concat([n, f], axis=1, join="inner")

# %%
result2
# Out:
#                  business_id  stars_x GoodForKids RestaurantsGoodForGroups  \
# 0     SZU9c8V2GuREDN5KgyHFJw        5        True                     True
# 1     eL4lyE7LNoXEMvpcJ8WNVw        5        True                     True
# 2     eL4lyE7LNoXEMvpcJ8WNVw        3         NaN                     True
# 3     SZU9c8V2GuREDN5KgyHFJw        5         NaN                     True
# 4     SZU9c8V2GuREDN5KgyHFJw        5       False                     True
# ...                      ...      ...         ...                      ...
# 3997                  #NAME?        5        True                    False
# 3998  q75UQjNm6AEK4XNnkDLxTQ        5       False                     True
# 3999  H-1qpp_77KggOAr9htUrEw        4       False                     True
# 4000  1FURjeGJi_LBXcJQg8eskw        4        True                    False
# 4001  1FURjeGJi_LBXcJQg8eskw        5        True                    False
#
#      RestaurantsAttire BusinessAcceptsCreditCards Caters  \
# ...

# %%
for i in range(4001,6001):
    m = df.loc[i]
    a = ast.literal_eval(m["attributes"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result3 = pd.concat([n, f], axis=1, join="inner")

# %%
result3
# Out:
#                  business_id  stars_x GoodForDancing BusinessAcceptsBitcoin  \
# 0     SZU9c8V2GuREDN5KgyHFJw        5           True                  False
# 1     eL4lyE7LNoXEMvpcJ8WNVw        5          False                  False
# 2     eL4lyE7LNoXEMvpcJ8WNVw        3            NaN                  False
# 3     SZU9c8V2GuREDN5KgyHFJw        5            NaN                  False
# 4     SZU9c8V2GuREDN5KgyHFJw        5            NaN                  False
# ...                      ...      ...            ...                    ...
# 5997  SZU9c8V2GuREDN5KgyHFJw        5            NaN                  False
# 5998  SZU9c8V2GuREDN5KgyHFJw        4            NaN                    NaN
# 5999  zbrIMldF_O1ZQ0vpUaaa8A        3            NaN                    NaN
# 6000  2nk4hq2oRfym8ROQ5iS47g        5            NaN                  False
# 6001  SZU9c8V2GuREDN5KgyHFJw        5            NaN                  False
#
#      HappyHour OutdoorSeating  \
# ...

# %%
for i in range(6001,8001):
    m = df.loc[i]
    a = ast.literal_eval(m["attributes"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result4 = pd.concat([n, f], axis=1, join="inner")

# %%
result4

# %%
for i in range(8001,10001):
    m = df.loc[i]
    a = ast.literal_eval(m["attributes"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result5 = pd.concat([n, f], axis=1, join="inner")

# %%
result5

# %%
for i in range (10001,12001):
    m = df.loc[i]
    a = ast.literal_eval(m["attributes"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result6 = pd.concat([n, f], axis=1, join="inner")

# %%
for i in range (12001,14001):
    m = df.loc[i]
    a = ast.literal_eval(m["attributes"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result7 = pd.concat([n, f], axis=1, join="inner")

# %%
for i in range (14001,16001):
    m = df.loc[i]
    a = ast.literal_eval(m["attributes"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result8 = pd.concat([n, f], axis=1, join="inner")

# %%
result8

# %%
for i in range (16001,18001):
    m = df.loc[i]
    a = ast.literal_eval(m["attributes"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result9 = pd.concat([n, f], axis=1, join="inner")

# %%
for i in range (18001,20001):
    m = df.loc[i]
    a = ast.literal_eval(m["attributes"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result10 = pd.concat([n, f], axis=1, join="inner")

# %%
for i in range (20001,22001):
    m = df.loc[i]
    a = ast.literal_eval(m["attributes"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result11 = pd.concat([n, f], axis=1, join="inner")

# %%
for i in range (22001,24001):
    m = df.loc[i]
    a = ast.literal_eval(m["attributes"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result12 = pd.concat([n, f], axis=1, join="inner")

# %%
for i in range (24001,26001):
    m = df.loc[i]
    a = ast.literal_eval(m["attributes"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result13 = pd.concat([n, f], axis=1, join="inner")

# %%
for i in range (26001,28001):
    m = df.loc[i]
    a = ast.literal_eval(m["attributes"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result14 = pd.concat([n, f], axis=1, join="inner")

# %%
for i in range (28001,30001):
    m = df.loc[i]
    a = ast.literal_eval(m["attributes"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result15 = pd.concat([n, f], axis=1, join="inner")

# %%
for i in range (30001,32001):
    m = df.loc[i]
    a = ast.literal_eval(m["attributes"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result16 = pd.concat([n, f], axis=1, join="inner")

# %%
for i in range (32001,34001):
    m = df.loc[i]
    a = ast.literal_eval(m["attributes"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result17 = pd.concat([n, f], axis=1, join="inner")

# %%
for i in range (34001,36001):
    m = df.loc[i]
    a = ast.literal_eval(m["attributes"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result18 = pd.concat([n, f], axis=1, join="inner")

# %%
for i in range (36001,38001):
    m = df.loc[i]
    a = ast.literal_eval(m["attributes"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result19 = pd.concat([n, f], axis=1, join="inner")

# %%
for i in range (38001,40001):
    m = df.loc[i]
    a = ast.literal_eval(m["attributes"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result20 = pd.concat([n, f], axis=1, join="inner")

# %%
for i in range (40001,42001):
    m = df.loc[i]
    a = ast.literal_eval(m["attributes"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result21 = pd.concat([n, f], axis=1, join="inner")

# %%
for i in range (42001,44001):
    m = df.loc[i]
    a = ast.literal_eval(m["attributes"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result22 = pd.concat([n, f], axis=1, join="inner")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-89f4df1461aa> in <module>
#       1 for i in range (42001,44001):
#       2     m = df.loc[i]
# ----> 3     a = ast.literal_eval(m["attributes"])
#       4     df1 = pd.DataFrame([a])
#       5     f = pd.concat([df1,f], axis=0, ignore_index=True)
#
# ~/opt/anaconda3/lib/python3.8/ast.py in literal_eval(node_or_string)
#      97                     return left - right
#      98         return _convert_signed_num(node)
# ---> 99     return _convert(node_or_string)
#     100
#     101
#
# ~/opt/anaconda3/lib/python3.8/ast.py in _convert(node)
#      96                 else:
#      97                     return left - right
# ---> 98         return _convert_signed_num(node)
#      99     return _convert(node_or_string)
#     100
#
# ~/opt/anaconda3/lib/python3.8/ast.py in _convert_signed_num(node)
# ...

# %%
for i in range (44001,44693):
    m = df.loc[i]
    a = ast.literal_eval(m["attributes"])
    df1 = pd.DataFrame([a])
    f = pd.concat([df1,f], axis=0, ignore_index=True)
    
result23 = pd.concat([n, f], axis=1, join="inner")

# %%
result21
# Out:
#                   business_id  stars_x RestaurantsTakeOut  HasTV  NoiseLevel  \
# 0      SZU9c8V2GuREDN5KgyHFJw        5               True  False  u'average'
# 1      eL4lyE7LNoXEMvpcJ8WNVw        5               True   True  u'average'
# 2      eL4lyE7LNoXEMvpcJ8WNVw        3               True  False    u'quiet'
# 3      SZU9c8V2GuREDN5KgyHFJw        5               True   True  u'average'
# 4      SZU9c8V2GuREDN5KgyHFJw        5               True   True   'average'
# ...                       ...      ...                ...    ...         ...
# 41997  QLHgjBHBoeIUoEvIPvjHnw        4               True  False  u'average'
# 41998  QBNATcq7Stx9LxcSq16W7w        5               True  False    u'quiet'
# 41999  QLHgjBHBoeIUoEvIPvjHnw        5               True  False    u'quiet'
# 42000  krTxH1a9kzWgwvt3PVH8pQ        5               True  False  u'average'
# 42001  YiSr-W5BBX6uXnhWPxk82Q        5               True  False  u'average'
#
# ...

# %%
result21.to_csv("result.csv")
